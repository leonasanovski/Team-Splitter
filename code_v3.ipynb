# %% [markdown]
# ## Making a football fair team splitter

# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from numpy import number
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from tabulate import tabulate #for creating tables

# %%
df = pd.read_csv('zoki_liga_formatted.csv')

# %%
df
# Out:
#     index         name position secondary_position  matches  goals  assists  \
# 0       1         Daco        D                 GK       36      5       11
# 1       2          Leo        D                 GK       34     40       19
# 2       3       Simikj        M                NaN       34     10       24
# 3       4         Stef        M                 GK       32     22       12
# 4       5         Neno       GK                NaN       29      0        6
# 5       6         Prem        A                NaN       27     38       19
# 6       7       Borjan        M                 GK       27     31       19
# 7       8        Ancho        D                NaN       27      2        0
# 8       9         Hito        A                NaN       26     57       22
# 9      10    Hristijan        D                NaN       25     14       21
# 10     11         Maki        D                 GK       23      9       16
# 11     12      Dzhoker        A                NaN       22     24       14
# 12     13       Grekos        M                NaN       22      7        5
# 13     14         Bale        D                NaN       13      2        2
# 14     15        Mario        M                NaN       11     13        8
# 15     16         Stec       GK                NaN       11      0        1
# 16     17         Dare        M                NaN       10     11        9
# 17     18        Lazo         A                NaN        9     10        7
# 18     19       Martin        M                NaN        9      9        7
# 19     20         Fich       GK                NaN        8      2        1
# 20     21        Nargo        M                NaN        4      4        3
# 21     22          Nuh       GK                NaN        4      0        1
# 22     23        Filip        M                NaN        4      1        0
# 23     24         Vule        M                NaN        3      8        6
# 24     25       Jancho        M                NaN        3      3        5
# 25     26       Davide        M                NaN        3      2        3
# 26     27        Nikec        A                NaN        2      1        2
# 27     28      Fishboi       GK                NaN        2      0        0
# 28     29        Silbo       GK                NaN        2      0        0
# 29     30          Teo        M                NaN        2      0        0
# 30     31       Gorjan        D                NaN        2      0        0
# 31     32        Theo         M                NaN        1      4        2
# 32     33     Nikolche        M                NaN        1      2        2
# 33     34       Bodan         A                NaN        1      0        3
# 34     35       Gjozo         A                NaN        1      2        1
# 35     36      Gashtar        A                NaN        1      1        1
# 36     37        Tomas        A                NaN        1      2        0
# 37     38          Jan        A                NaN        1      1        1
# 38     39      Stefan         D                NaN        1      1        0
# 39     40          Ron        M                NaN        1      1        0
# 40     41        Dimov        M                NaN        1      0        1
# 41     42         Hris        D                NaN        1      0        0
# 42     43         Leon        M                NaN        1      0        0
# 43     44  Ter Stegen        GK                NaN        1      0        0
#
#     goal_contribution  gc_per_match  hat-trick  ...  \
# 0                  16          0.44          0  ...
# 1                  59          1.74          3  ...
# 2                  34          1.00          0  ...
# 3                  34          1.06          2  ...
# 4                   6          0.21          0  ...
# 5                  57          2.11          7  ...
# 6                  50          1.85          4  ...
# 7                   2          0.07          0  ...
# 8                  79          3.04         10  ...
# 9                  35          1.40          0  ...
# 10                 25          1.09          0  ...
# 11                 38          1.73          1  ...
# 12                 12          0.55          0  ...
# 13                  4          0.31          0  ...
# 14                 21          1.91          0  ...
# 15                  1          0.09          0  ...
# 16                 20          2.00          1  ...
# 17                 17          1.89          1  ...
# 18                 16          1.78          2  ...
# 19                  3          0.38          0  ...
# 20                  7          1.75          0  ...
# 21                  1          0.25          0  ...
# 22                  1          0.25          0  ...
# 23                 14          4.67          1  ...
# 24                  8          2.67          0  ...
# 25                  5          1.67          0  ...
# 26                  3          1.50          0  ...
# 27                  0          0.00          0  ...
# 28                  0          0.00          0  ...
# 29                  0          0.00          0  ...
# 30                  0          0.00          0  ...
# 31                  6          6.00          1  ...
# 32                  4          4.00          0  ...
# 33                  3          3.00          0  ...
# 34                  3          3.00          0  ...
# 35                  2          2.00          0  ...
# 36                  2          2.00          0  ...
# 37                  2          2.00          0  ...
# 38                  1          1.00          0  ...
# 39                  1          1.00          0  ...
# 40                  1          1.00          0  ...
# 41                  0          0.00          0  ...
# 42                  0          0.00          0  ...
# 43                  0          0.00          0  ...
#
#     interceptions_overall_ability  fouls_commiting  stamina_rating  \
# 0                            5.50             4.25            5.00
# 1                            8.50             5.00            8.50
# 2                            5.25             2.75            4.25
# 3                            5.00             3.00            5.50
# 4                            3.00             8.50            5.00
# 5                            6.75             2.75            6.25
# 6                            4.50             4.25            5.50
# 7                            4.00             5.75            5.25
# 8                            8.25             9.00            8.75
# 9                            6.50             3.50            4.00
# 10                           8.25             3.50            8.75
# 11                           6.00             2.00            7.00
# 12                           4.50             3.50            6.00
# 13                           6.00             4.75            3.75
# 14                           8.50             7.00            8.25
# 15                           1.00             1.00            2.25
# 16                           6.75             2.00            6.00
# 17                           4.75             6.50            7.00
# 18                           8.50             3.25            8.25
# 19                           5.00             3.25            6.00
# 20                           6.00             6.00            6.00
# 21                           1.50             1.00            2.50
# 22                           4.00             2.33            3.67
# 23                           8.50             2.75            9.25
# 24                           5.50             5.00            6.00
# 25                           6.33             6.33            7.33
# 26                           3.50             3.00            6.00
# 27                           1.50             2.25            2.50
# 28                           1.00             1.00            1.50
# 29                           6.00             3.00            4.00
# 30                           4.50             5.00            5.00
# 31                            NaN              NaN             NaN
# 32                           4.00             2.00            4.00
# 33                            NaN              NaN             NaN
# 34                           7.00             4.50            6.50
# 35                           6.00             9.00            7.00
# 36                           6.00             5.50            8.00
# 37                           5.00             3.00            6.00
# 38                            NaN              NaN             NaN
# 39                           7.00             4.00            7.00
# 40                           6.00             4.00            6.00
# 41                            NaN              NaN             NaN
# 42                           4.50             5.50            6.00
# 43                           5.00             3.50            7.00
#
#    positions_played leadership_measure  passing  physical  gk_ability  skill  \
# 0              5.00               3.25     4.00      5.75        9.50   3.00
# 1              9.00               7.50     8.25      9.00        7.25   7.00
# 2              4.00               2.75     7.50      2.00        1.25   7.50
# 3              4.75               5.75     4.25      4.50        5.50   3.50
# 4              2.75               1.00     3.25      5.75        8.00   2.50
# 5              5.75               6.50     7.75      6.75        3.25   8.50
# 6              4.50               4.75     5.25      8.25        4.75   5.50
# 7              2.00               2.75     2.00      3.00        1.50   2.00
# 8              6.00               7.00     7.50      8.00        3.00   8.00
# 9              4.75               4.75     6.25      8.00        3.00   5.50
# 10             7.50               7.00     7.00      5.75        5.75   6.25
# 11             4.50               2.75     6.25      4.50        2.50   7.00
# 12             4.50               2.00     4.50      3.25        1.75   3.75
# 13             2.75               7.25     3.50      8.75        4.00   2.75
# 14             5.75               7.25     8.25      7.25        2.75   7.50
# 15             1.00               1.25     3.00      1.50        8.00   1.25
# 16             6.00               3.25     8.25      4.25        2.00   7.25
# 17             5.25               3.25     5.00      8.25        2.25   5.25
# 18             8.25               7.50     9.00      8.75        3.50   9.25
# 19             5.25               3.00     5.25      6.25        9.00   4.25
# 20             4.00               4.00     7.00      4.00        1.00   8.00
# 21             1.00               3.25     3.00      2.25        7.25   1.50
# 22             4.33               2.33     4.00      3.00        3.67   3.67
# 23             7.75               8.25     8.75      9.75        4.50   9.50
# 24             5.00               1.50     5.50      4.00        1.00   6.00
# 25             6.00               5.33     8.00      6.67        1.50   9.00
# 26             3.50               3.50     4.50      5.50        1.00   3.50
# 27             2.00               1.00     1.50      1.25        2.50   1.25
# 28             1.00               1.00     1.00      1.00        8.50   1.00
# 29             4.00               2.50     7.50      3.50        1.00   7.00
# 30             3.00               3.00     3.50      7.00        3.50   2.50
# 31              NaN                NaN      NaN       NaN         NaN    NaN
# 32             3.00               4.00     4.00      4.00        1.00   3.00
# 33              NaN                NaN      NaN       NaN         NaN    NaN
# 34             5.00               4.50     6.50      7.00        2.00   7.00
# 35             6.00               4.00     7.00      7.00        1.00   7.00
# 36             6.00               4.00     7.00      8.00        1.50   7.50
# 37             5.00               5.00     7.00      4.00        2.00   8.00
# 38              NaN                NaN      NaN       NaN         NaN    NaN
# 39             6.00               4.00     6.00      6.00        1.00   7.00
# 40             4.00               4.00     5.00      5.00        1.00   5.00
# 41              NaN                NaN      NaN       NaN         NaN    NaN
# 42             3.50               4.00     5.00      6.50        1.00   3.50
# 43             3.50               3.00     5.00      8.00        8.00   5.50
#
#     positioning_sense
# 0                4.50
# 1                8.00
# 2                6.50
# 3                4.75
# 4                2.25
# 5                8.00
# 6                7.00
# 7                3.75
# 8                8.25
# 9                7.00
# 10               8.00
# 11               7.00
# 12               5.25
# 13               4.75
# 14               8.50
# 15               2.50
# 16               7.75
# 17               5.25
# 18               9.00
# 19               4.25
# 20               6.00
# 21               2.00
# 22               4.67
# 23               9.25
# 24               5.00
# 25               6.33
# 26               3.50
# 27               1.33
# 28               1.00
# 29               6.50
# 30               3.50
# 31                NaN
# 32               4.00
# 33                NaN
# 34               7.50
# 35               6.00
# 36               6.50
# 37               7.00
# 38                NaN
# 39               7.00
# 40               5.00
# 41                NaN
# 42               4.50
# 43               5.50
#
# [44 rows x 33 columns]

# %%
df = df.drop(columns=['index','goal_contribution','owngoals','freekicks','penalty_saves','penalty_stats','w','losses','nominations','gotm'])

# %%
df.head(10)
# Out:
#         name position secondary_position  matches  goals  assists  \
# 0       Daco        D                 GK       36      5       11
# 1        Leo        D                 GK       34     40       19
# 2     Simikj        M                NaN       34     10       24
# 3       Stef        M                 GK       32     22       12
# 4       Neno       GK                NaN       29      0        6
# 5       Prem        A                NaN       27     38       19
# 6     Borjan        M                 GK       27     31       19
# 7      Ancho        D                NaN       27      2        0
# 8       Hito        A                NaN       26     57       22
# 9  Hristijan        D                NaN       25     14       21
#
#    gc_per_match  hat-trick  hat-trick-assists  w_percentage  ...  \
# 0          0.44          0                  0          0.36  ...
# 1          1.74          3                  3          0.35  ...
# 2          1.00          0                  1          0.41  ...
# 3          1.06          2                  0          0.44  ...
# 4          0.21          0                  0          0.38  ...
# 5          2.11          7                  0          0.41  ...
# 6          1.85          4                  1          0.63  ...
# 7          0.07          0                  0          0.37  ...
# 8          3.04         10                  2          0.46  ...
# 9          1.40          0                  1          0.52  ...
#
#    interceptions_overall_ability  fouls_commiting  stamina_rating  \
# 0                           5.50             4.25            5.00
# 1                           8.50             5.00            8.50
# 2                           5.25             2.75            4.25
# 3                           5.00             3.00            5.50
# 4                           3.00             8.50            5.00
# 5                           6.75             2.75            6.25
# 6                           4.50             4.25            5.50
# 7                           4.00             5.75            5.25
# 8                           8.25             9.00            8.75
# 9                           6.50             3.50            4.00
#
#    positions_played  leadership_measure  passing  physical  gk_ability  skill  \
# 0              5.00                3.25     4.00      5.75        9.50    3.0
# 1              9.00                7.50     8.25      9.00        7.25    7.0
# 2              4.00                2.75     7.50      2.00        1.25    7.5
# 3              4.75                5.75     4.25      4.50        5.50    3.5
# 4              2.75                1.00     3.25      5.75        8.00    2.5
# 5              5.75                6.50     7.75      6.75        3.25    8.5
# 6              4.50                4.75     5.25      8.25        4.75    5.5
# 7              2.00                2.75     2.00      3.00        1.50    2.0
# 8              6.00                7.00     7.50      8.00        3.00    8.0
# 9              4.75                4.75     6.25      8.00        3.00    5.5
#
#    positioning_sense
# 0               4.50
# 1               8.00
# 2               6.50
# 3               4.75
# 4               2.25
# 5               8.00
# 6               7.00
# 7               3.75
# 8               8.25
# 9               7.00
#
# [10 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   name                           44 non-null     object
#  1   position                       44 non-null     object
#  2   secondary_position             5 non-null      object
#  3   matches                        44 non-null     int64
#  4   goals                          44 non-null     int64
#  5   assists                        44 non-null     int64
#  6   gc_per_match                   44 non-null     float64
#  7   hat-trick                      44 non-null     int64
#  8   hat-trick-assists              44 non-null     int64
#  9   w_percentage                   44 non-null     float64
#  10  loss_percentage                44 non-null     float64
#  11  motm                           44 non-null     int64
#  12  potm                           44 non-null     int64
#  13  interceptions_overall_ability  40 non-null     float64
#  14  fouls_commiting                40 non-null     float64
#  15  stamina_rating                 40 non-null     float64
#  16  positions_played               40 non-null     float64
#  17  leadership_measure             40 non-null     float64
#  18  passing                        40 non-null     float64
#  19  physical                       40 non-null     float64
#  20  gk_ability                     40 non-null     float64
#  21  skill                          40 non-null     float64
#  22  positioning_sense              40 non-null     float64
# dtypes: float64(13), int64(7), object(3)
# memory usage: 8.0+ KB

# %%
df.columns.tolist()
# Out:
# ['name',
#  'position',
#  'secondary_position',
#  'matches',
#  'goals',
#  'assists',
#  'gc_per_match',
#  'hat-trick',
#  'hat-trick-assists',
#  'w_percentage',
#  'loss_percentage',
#  'motm',
#  'potm',
#  'interceptions_overall_ability',
#  'fouls_commiting',
#  'stamina_rating',
#  'positions_played',
#  'leadership_measure',
#  'passing',
#  'physical',
#  'gk_ability',
#  'skill',
#  'positioning_sense']

# %% [markdown]
# ## Attackers
# The formula and the stats are set depending on the performance and on the attributes I think football is requiring for an ATTACKER to be complete.
# I add more bias to the goals assists, to the physicality, to the skill and to passing.
#
# #### I will try to use the Z-Score now to calculate for the attackers, their ratings for the sheet so i can make the split in a more better way, using the important stats for the position I need.

# %%
attackers = df[df['position'] == 'A'].copy()

# %%
weights_attack = {
    'goals': 0.29,
    'stamina_rating': 0.13,
    'gc_per_match': 0.12,
    'physical': 0.09,
    'assists': 0.08,
    'positioning_sense': 0.08,
    'positions_played': 0.08,
    'passing': 0.07,
    'leadership_measure': 0.07,
    'skill': 0.06,
    'fouls_commiting': -0.07
}

# %%
attacker_features = list(weights_attack.keys())
X_attack = attackers[attacker_features].apply(pd.to_numeric, errors="coerce")

# %%
mu_attack = X_attack.mean()
sigma_attack = X_attack.std(ddof=0)
sigma_attack = sigma_attack.replace(0, 1e-9)
Z_attack = (X_attack - mu_attack) / sigma_attack
w_attack = pd.Series(weights_attack) #weihts
attacker_score = (Z_attack * w_attack).sum(axis=1)
attackers["attacker_score"] = attacker_score
attackers["rating"] = 50 + 10 * attacker_score

# %%
attackers_matches = df[df['position'] == 'A']['matches'].copy()

# %%
min_matches_attack = attackers_matches.min()
max_matches_attack = attackers_matches.max()
experience_factor_a = 0.85 + 0.15 * (attackers_matches - min_matches_attack) / (max_matches_attack - min_matches_attack)
attackers['rating'] = attackers['rating'] * experience_factor_a

# %%
attackers = attackers.sort_values(by='rating', ascending=False)

# %%
attackers[['name','rating']].round(2)
# Out:
#        name  rating
# 8      Hito   66.30
# 5      Prem   58.35
# 11  Dzhoker   47.97
# 36    Tomas   42.85
# 34   Gjozo    42.03
# 33   Bodan    41.83
# 17    Lazo    41.56
# 35  Gashtar   39.77
# 37      Jan   38.77
# 26    Nikec   32.28

# %%
avg_attacker_rating = round((attackers['rating'].sum())/attackers['rating'].size, 3)
print(f"Average Rating of Attacker is {avg_attacker_rating}")
# Out:
# Average Rating of Attacker is 45.171

# %% [markdown]
# ## Midfield

# %%
midfielders = df[df['position'] == 'M'].copy()

# %%
midfielders
# Out:
#         name position secondary_position  matches  goals  assists  \
# 2     Simikj        M                NaN       34     10       24
# 3       Stef        M                 GK       32     22       12
# 6     Borjan        M                 GK       27     31       19
# 12    Grekos        M                NaN       22      7        5
# 14     Mario        M                NaN       11     13        8
# 16      Dare        M                NaN       10     11        9
# 18    Martin        M                NaN        9      9        7
# 20     Nargo        M                NaN        4      4        3
# 22     Filip        M                NaN        4      1        0
# 23      Vule        M                NaN        3      8        6
# 24    Jancho        M                NaN        3      3        5
# 25    Davide        M                NaN        3      2        3
# 29       Teo        M                NaN        2      0        0
# 31     Theo         M                NaN        1      4        2
# 32  Nikolche        M                NaN        1      2        2
# 39       Ron        M                NaN        1      1        0
# 40     Dimov        M                NaN        1      0        1
# 42      Leon        M                NaN        1      0        0
#
#     gc_per_match  hat-trick  hat-trick-assists  w_percentage  ...  \
# 2           1.00          0                  1          0.41  ...
# 3           1.06          2                  0          0.44  ...
# 6           1.85          4                  1          0.63  ...
# 12          0.55          0                  0          0.23  ...
# 14          1.91          0                  0          0.55  ...
# 16          2.00          1                  1          0.30  ...
# 18          1.78          2                  0          0.33  ...
# 20          1.75          0                  0          0.25  ...
# 22          0.25          0                  0          0.50  ...
# 23          4.67          1                  1          1.00  ...
# 24          2.67          0                  1          0.33  ...
# 25          1.67          0                  0          0.00  ...
# 29          0.00          0                  0          0.50  ...
# 31          6.00          1                  0          1.00  ...
# 32          4.00          0                  0          0.00  ...
# 39          1.00          0                  0          1.00  ...
# 40          1.00          0                  0          0.00  ...
# 42          0.00          0                  0          0.00  ...
#
#     interceptions_overall_ability  fouls_commiting  stamina_rating  \
# 2                            5.25             2.75            4.25
# 3                            5.00             3.00            5.50
# 6                            4.50             4.25            5.50
# 12                           4.50             3.50            6.00
# 14                           8.50             7.00            8.25
# 16                           6.75             2.00            6.00
# 18                           8.50             3.25            8.25
# 20                           6.00             6.00            6.00
# 22                           4.00             2.33            3.67
# 23                           8.50             2.75            9.25
# 24                           5.50             5.00            6.00
# 25                           6.33             6.33            7.33
# 29                           6.00             3.00            4.00
# 31                            NaN              NaN             NaN
# 32                           4.00             2.00            4.00
# 39                           7.00             4.00            7.00
# 40                           6.00             4.00            6.00
# 42                           4.50             5.50            6.00
#
#     positions_played  leadership_measure  passing  physical  gk_ability  \
# 2               4.00                2.75     7.50      2.00        1.25
# 3               4.75                5.75     4.25      4.50        5.50
# 6               4.50                4.75     5.25      8.25        4.75
# 12              4.50                2.00     4.50      3.25        1.75
# 14              5.75                7.25     8.25      7.25        2.75
# 16              6.00                3.25     8.25      4.25        2.00
# 18              8.25                7.50     9.00      8.75        3.50
# 20              4.00                4.00     7.00      4.00        1.00
# 22              4.33                2.33     4.00      3.00        3.67
# 23              7.75                8.25     8.75      9.75        4.50
# 24              5.00                1.50     5.50      4.00        1.00
# 25              6.00                5.33     8.00      6.67        1.50
# 29              4.00                2.50     7.50      3.50        1.00
# 31               NaN                 NaN      NaN       NaN         NaN
# 32              3.00                4.00     4.00      4.00        1.00
# 39              6.00                4.00     6.00      6.00        1.00
# 40              4.00                4.00     5.00      5.00        1.00
# 42              3.50                4.00     5.00      6.50        1.00
#
#     skill  positioning_sense
# 2    7.50               6.50
# 3    3.50               4.75
# 6    5.50               7.00
# 12   3.75               5.25
# 14   7.50               8.50
# 16   7.25               7.75
# 18   9.25               9.00
# 20   8.00               6.00
# 22   3.67               4.67
# 23   9.50               9.25
# 24   6.00               5.00
# 25   9.00               6.33
# 29   7.00               6.50
# 31    NaN                NaN
# 32   3.00               4.00
# 39   7.00               7.00
# 40   5.00               5.00
# 42   3.50               4.50
#
# [18 rows x 23 columns]

# %%
weights_midfielders = {
    'passing': 0.15,
    'assists': 0.15,
    'skill': 0.13,
    'positioning_sense': 0.13,
    'stamina_rating': 0.13,
    'interceptions_overall_ability': 0.12,
    'goals': 0.1,
    'leadership_measure': 0.09,
    'physical': 0.07,
    'gc_per_match': 0.05,
    'positions_played': 0.05,
    'fouls_commiting': -0.07
}

# %%
midfielders_features = list(weights_midfielders.keys())
X_midfield = midfielders[midfielders_features].apply(pd.to_numeric, errors="coerce")

# %%
mu_midfield = X_midfield.mean()
sigma_midfield = X_midfield.std(ddof=0)
sigma_midfield = sigma_midfield.replace(0, 1e-9)
Z_midfield = (X_midfield - mu_midfield) / sigma_midfield
w_midfield = pd.Series(weights_midfielders)
midfielder_score = (Z_midfield * w_midfield).sum(axis=1)
midfielders['midfielder_score'] = midfielder_score
midfielders["rating"] = 50 + 10 * midfielder_score

# %%
midfielders_matches = df[df['position'] == 'M']['matches'].copy()

# %%
min_matches_midfield = midfielders_matches.min()
max_matches_midfield = midfielders_matches.max()
experience_factor_m = 0.85 + 0.15 * (midfielders_matches - min_matches_midfield) / (max_matches_midfield - min_matches_midfield)
midfielders['rating'] = midfielders['rating'] * experience_factor_m

# %%
midfielders = midfielders.sort_values(by='rating', ascending=False)

# %%
midfielders[['name','rating']].round(3)
# Out:
#         name  rating
# 23      Vule  57.724
# 18    Martin  57.533
# 14     Mario  53.982
# 6     Borjan  52.625
# 2     Simikj  52.505
# 16      Dare  49.676
# 3       Stef  47.312
# 25    Davide  45.849
# 39       Ron  42.867
# 31     Theo   42.536
# 20     Nargo  41.829
# 12    Grekos  40.101
# 29       Teo  39.110
# 24    Jancho  38.611
# 40     Dimov  37.473
# 42      Leon  34.503
# 32  Nikolche  33.597
# 22     Filip  32.512

# %%
midfielders[['name','rating']].round(3)
# Out:
#         name  rating
# 23      Vule  57.724
# 18    Martin  57.533
# 14     Mario  53.982
# 6     Borjan  52.625
# 2     Simikj  52.505
# 16      Dare  49.676
# 3       Stef  47.312
# 25    Davide  45.849
# 39       Ron  42.867
# 31     Theo   42.536
# 20     Nargo  41.829
# 12    Grekos  40.101
# 29       Teo  39.110
# 24    Jancho  38.611
# 40     Dimov  37.473
# 42      Leon  34.503
# 32  Nikolche  33.597
# 22     Filip  32.512

# %%
avg_midfielders_rating = round((midfielders['rating'].sum())/midfielders['rating'].size, 3)
print(f"Average Rating of Midfielder is {avg_midfielders_rating}")
# Out:
# Average Rating of Midfielder is 44.464

# %% [markdown]
# ## Defenders

# %%
defenders = df[df['position'] =='D'].copy()

# %%
defenders
# Out:
#          name position secondary_position  matches  goals  assists  \
# 0        Daco        D                 GK       36      5       11
# 1         Leo        D                 GK       34     40       19
# 7       Ancho        D                NaN       27      2        0
# 9   Hristijan        D                NaN       25     14       21
# 10       Maki        D                 GK       23      9       16
# 13       Bale        D                NaN       13      2        2
# 30     Gorjan        D                NaN        2      0        0
# 38    Stefan         D                NaN        1      1        0
# 41       Hris        D                NaN        1      0        0
#
#     gc_per_match  hat-trick  hat-trick-assists  w_percentage  ...  \
# 0           0.44          0                  0          0.36  ...
# 1           1.74          3                  3          0.35  ...
# 7           0.07          0                  0          0.37  ...
# 9           1.40          0                  1          0.52  ...
# 10          1.09          0                  1          0.52  ...
# 13          0.31          0                  0          0.23  ...
# 30          0.00          0                  0          0.50  ...
# 38          1.00          0                  0          1.00  ...
# 41          0.00          0                  0          0.00  ...
#
#     interceptions_overall_ability  fouls_commiting  stamina_rating  \
# 0                            5.50             4.25            5.00
# 1                            8.50             5.00            8.50
# 7                            4.00             5.75            5.25
# 9                            6.50             3.50            4.00
# 10                           8.25             3.50            8.75
# 13                           6.00             4.75            3.75
# 30                           4.50             5.00            5.00
# 38                            NaN              NaN             NaN
# 41                            NaN              NaN             NaN
#
#     positions_played  leadership_measure  passing  physical  gk_ability  \
# 0               5.00                3.25     4.00      5.75        9.50
# 1               9.00                7.50     8.25      9.00        7.25
# 7               2.00                2.75     2.00      3.00        1.50
# 9               4.75                4.75     6.25      8.00        3.00
# 10              7.50                7.00     7.00      5.75        5.75
# 13              2.75                7.25     3.50      8.75        4.00
# 30              3.00                3.00     3.50      7.00        3.50
# 38               NaN                 NaN      NaN       NaN         NaN
# 41               NaN                 NaN      NaN       NaN         NaN
#
#     skill  positioning_sense
# 0    3.00               4.50
# 1    7.00               8.00
# 7    2.00               3.75
# 9    5.50               7.00
# 10   6.25               8.00
# 13   2.75               4.75
# 30   2.50               3.50
# 38    NaN                NaN
# 41    NaN                NaN
#
# [9 rows x 23 columns]

# %%
weights_defenders = {
    'interceptions_overall_ability': 0.2,
    'positioning_sense': 0.15,
    'physical': 0.15,
    'stamina_rating': 0.13,
    'leadership_measure': 0.1,
    'passing': 0.1,
    'positions_played': 0.07,
    'goals': 0.07,
    'gc_per_match': 0.05,
    'skill': 0.04,
    'assists': 0.04,
    'fouls_commiting': -0.1
}

# %%
defenders_features = list(weights_defenders.keys())
X_defenders = defenders[defenders_features].apply(pd.to_numeric, errors="coerce")

# %%
mu_defenders = X_defenders.mean()
sigma_defenders = X_defenders.std(ddof=0)
sigma_defenders = sigma_defenders.replace(0, 1e-9)
Z_defenders = (X_defenders - mu_defenders) / sigma_defenders
w_defenders = pd.Series(weights_defenders)
defenders_score = (Z_defenders * w_defenders).sum(axis=1)
defenders['defenders_score'] = defenders_score
defenders['rating'] = 50 + 10 * defenders_score

# %%
defenders_matches = df[df['position'] == 'D']['matches'].copy()

# %%
min_matches_defenders = defenders_matches.min()
max_matches_defenders = defenders_matches.max()
experience_factor_d = 0.85 + 0.15 * (defenders_matches - min_matches_defenders) / (max_matches_defenders - min_matches_defenders)

defenders['rating'] = defenders['rating'] * experience_factor_d

# %%
defenders = defenders.sort_values(by='rating', ascending=False)

# %%
defenders[['name','rating']].round(3)
# Out:
#          name  rating
# 1         Leo  65.176
# 10       Maki  57.731
# 9   Hristijan  52.312
# 0        Daco  45.519
# 13       Bale  42.832
# 38    Stefan   42.071
# 41       Hris  41.331
# 30     Gorjan  35.208
# 7       Ancho  34.472

# %%
avg_defenders_rating = round((defenders['rating'].sum())/defenders['rating'].size, 3)
print(f'Average Defenders Rating is {avg_defenders_rating}')
# Out:
# Average Defenders Rating is 46.295

# %% [markdown]
# ## Goalkeepers

# %%
goalkeepers = df[df['position'] =='GK'].copy()

# %%
goalkeepers
# Out:
#            name position secondary_position  matches  goals  assists  \
# 4          Neno       GK                NaN       29      0        6
# 15         Stec       GK                NaN       11      0        1
# 19         Fich       GK                NaN        8      2        1
# 21          Nuh       GK                NaN        4      0        1
# 27      Fishboi       GK                NaN        2      0        0
# 28        Silbo       GK                NaN        2      0        0
# 43  Ter Stegen        GK                NaN        1      0        0
#
#     gc_per_match  hat-trick  hat-trick-assists  w_percentage  ...  \
# 4           0.21          0                  0          0.38  ...
# 15          0.09          0                  0          0.55  ...
# 19          0.38          0                  0          0.25  ...
# 21          0.25          0                  0          0.50  ...
# 27          0.00          0                  0          0.50  ...
# 28          0.00          0                  0          0.50  ...
# 43          0.00          0                  0          0.00  ...
#
#     interceptions_overall_ability  fouls_commiting  stamina_rating  \
# 4                             3.0             8.50            5.00
# 15                            1.0             1.00            2.25
# 19                            5.0             3.25            6.00
# 21                            1.5             1.00            2.50
# 27                            1.5             2.25            2.50
# 28                            1.0             1.00            1.50
# 43                            5.0             3.50            7.00
#
#     positions_played  leadership_measure  passing  physical  gk_ability  \
# 4               2.75                1.00     3.25      5.75        8.00
# 15              1.00                1.25     3.00      1.50        8.00
# 19              5.25                3.00     5.25      6.25        9.00
# 21              1.00                3.25     3.00      2.25        7.25
# 27              2.00                1.00     1.50      1.25        2.50
# 28              1.00                1.00     1.00      1.00        8.50
# 43              3.50                3.00     5.00      8.00        8.00
#
#     skill  positioning_sense
# 4    2.50               2.25
# 15   1.25               2.50
# 19   4.25               4.25
# 21   1.50               2.00
# 27   1.25               1.33
# 28   1.00               1.00
# 43   5.50               5.50
#
# [7 rows x 23 columns]

# %%
goalkeepers[['name','gk_ability']].round(3)
# Out:
#            name  gk_ability
# 4          Neno        8.00
# 15         Stec        8.00
# 19         Fich        9.00
# 21          Nuh        7.25
# 27      Fishboi        2.50
# 28        Silbo        8.50
# 43  Ter Stegen         8.00

# %%
weights_goalkeepers = {
    'gk_ability': 0.65,
    'passing': 0.13, 
    'positioning_sense': 0.1,
    'leadership_measure': 0.07,
    'gc_per_match': 0.05
}

# %%
goalkeepers_features = list(weights_goalkeepers.keys())
X_goalkeepers = goalkeepers[goalkeepers_features].apply(pd.to_numeric, errors="coerce")

# %%
mu_goalkeepers = X_goalkeepers.mean()
sigma_goalkeepers = X_goalkeepers.std(ddof=0)
sigma_goalkeepers = sigma_goalkeepers.replace(0, 1e-9)
Z_goalkeepers = (X_goalkeepers - mu_goalkeepers) / sigma_goalkeepers
w_goalkeepers = pd.Series(weights_goalkeepers)
goalkeepers_score = (Z_goalkeepers * w_goalkeepers).sum(axis=1)
goalkeepers['goalkeepers_score'] = goalkeepers_score
goalkeepers['rating'] = 50 + 10 * goalkeepers_score

# %%
goalkeepers_matches = df[df['position'] == 'GK']['matches'].copy()

# %%
min_matches_goalkeepers = goalkeepers_matches.min()
max_matches_goalkeepers = goalkeepers_matches.max()
experience_factor_gk = 0.85 + 0.15 * (goalkeepers_matches - min_matches_goalkeepers) / (max_matches_goalkeepers - min_matches_goalkeepers)

goalkeepers['rating'] = goalkeepers['rating'] * experience_factor_gk

# %%
goalkeepers = goalkeepers.sort_values(by='rating', ascending=False)

# %%
goalkeepers[['name','rating']].round(3)
# Out:
#            name  rating
# 19         Fich  53.167
# 4          Neno  51.605
# 43  Ter Stegen   47.559
# 15         Stec  46.348
# 21          Nuh  43.759
# 28        Silbo  42.456
# 27      Fishboi  26.586

# %% [markdown]
# ## Merging the ratings

# %%
df_with_ratings = pd.concat([goalkeepers,defenders,midfielders,attackers], ignore_index=True)

# %%
df_with_ratings
# Out:
#            name position secondary_position  matches  goals  assists  \
# 0          Fich       GK                NaN        8      2        1
# 1          Neno       GK                NaN       29      0        6
# 2   Ter Stegen        GK                NaN        1      0        0
# 3          Stec       GK                NaN       11      0        1
# 4           Nuh       GK                NaN        4      0        1
# 5         Silbo       GK                NaN        2      0        0
# 6       Fishboi       GK                NaN        2      0        0
# 7           Leo        D                 GK       34     40       19
# 8          Maki        D                 GK       23      9       16
# 9     Hristijan        D                NaN       25     14       21
# 10         Daco        D                 GK       36      5       11
# 11         Bale        D                NaN       13      2        2
# 12      Stefan         D                NaN        1      1        0
# 13         Hris        D                NaN        1      0        0
# 14       Gorjan        D                NaN        2      0        0
# 15        Ancho        D                NaN       27      2        0
# 16         Vule        M                NaN        3      8        6
# 17       Martin        M                NaN        9      9        7
# 18        Mario        M                NaN       11     13        8
# 19       Borjan        M                 GK       27     31       19
# 20       Simikj        M                NaN       34     10       24
# 21         Dare        M                NaN       10     11        9
# 22         Stef        M                 GK       32     22       12
# 23       Davide        M                NaN        3      2        3
# 24          Ron        M                NaN        1      1        0
# 25        Theo         M                NaN        1      4        2
# 26        Nargo        M                NaN        4      4        3
# 27       Grekos        M                NaN       22      7        5
# 28          Teo        M                NaN        2      0        0
# 29       Jancho        M                NaN        3      3        5
# 30        Dimov        M                NaN        1      0        1
# 31         Leon        M                NaN        1      0        0
# 32     Nikolche        M                NaN        1      2        2
# 33        Filip        M                NaN        4      1        0
# 34         Hito        A                NaN       26     57       22
# 35         Prem        A                NaN       27     38       19
# 36      Dzhoker        A                NaN       22     24       14
# 37        Tomas        A                NaN        1      2        0
# 38       Gjozo         A                NaN        1      2        1
# 39       Bodan         A                NaN        1      0        3
# 40        Lazo         A                NaN        9     10        7
# 41      Gashtar        A                NaN        1      1        1
# 42          Jan        A                NaN        1      1        1
# 43        Nikec        A                NaN        2      1        2
#
#     gc_per_match  hat-trick  hat-trick-assists  w_percentage  ...  passing  \
# 0           0.38          0                  0          0.25  ...     5.25
# 1           0.21          0                  0          0.38  ...     3.25
# 2           0.00          0                  0          0.00  ...     5.00
# 3           0.09          0                  0          0.55  ...     3.00
# 4           0.25          0                  0          0.50  ...     3.00
# 5           0.00          0                  0          0.50  ...     1.00
# 6           0.00          0                  0          0.50  ...     1.50
# 7           1.74          3                  3          0.35  ...     8.25
# 8           1.09          0                  1          0.52  ...     7.00
# 9           1.40          0                  1          0.52  ...     6.25
# 10          0.44          0                  0          0.36  ...     4.00
# 11          0.31          0                  0          0.23  ...     3.50
# 12          1.00          0                  0          1.00  ...      NaN
# 13          0.00          0                  0          0.00  ...      NaN
# 14          0.00          0                  0          0.50  ...     3.50
# 15          0.07          0                  0          0.37  ...     2.00
# 16          4.67          1                  1          1.00  ...     8.75
# 17          1.78          2                  0          0.33  ...     9.00
# 18          1.91          0                  0          0.55  ...     8.25
# 19          1.85          4                  1          0.63  ...     5.25
# 20          1.00          0                  1          0.41  ...     7.50
# 21          2.00          1                  1          0.30  ...     8.25
# 22          1.06          2                  0          0.44  ...     4.25
# 23          1.67          0                  0          0.00  ...     8.00
# 24          1.00          0                  0          1.00  ...     6.00
# 25          6.00          1                  0          1.00  ...      NaN
# 26          1.75          0                  0          0.25  ...     7.00
# 27          0.55          0                  0          0.23  ...     4.50
# 28          0.00          0                  0          0.50  ...     7.50
# 29          2.67          0                  1          0.33  ...     5.50
# 30          1.00          0                  0          0.00  ...     5.00
# 31          0.00          0                  0          0.00  ...     5.00
# 32          4.00          0                  0          0.00  ...     4.00
# 33          0.25          0                  0          0.50  ...     4.00
# 34          3.04         10                  2          0.46  ...     7.50
# 35          2.11          7                  0          0.41  ...     7.75
# 36          1.73          1                  1          0.32  ...     6.25
# 37          2.00          0                  0          0.00  ...     7.00
# 38          3.00          0                  0          1.00  ...     6.50
# 39          3.00          0                  1          0.00  ...      NaN
# 40          1.89          1                  0          0.33  ...     5.00
# 41          2.00          0                  0          1.00  ...     7.00
# 42          2.00          0                  0          0.00  ...     7.00
# 43          1.50          0                  0          0.50  ...     4.50
#
#     physical  gk_ability  skill  positioning_sense  goalkeepers_score  \
# 0       6.25        9.00   4.25               4.25           0.990595
# 1       5.75        8.00   2.50               2.25           0.160533
# 2       8.00        8.00   5.50               5.50           0.595142
# 3       1.50        8.00   1.25               2.50           0.129444
# 4       2.25        7.25   1.50               2.00           0.052531
# 5       1.00        8.50   1.00               1.00          -0.036450
# 6       1.25        2.50   1.25               1.33          -1.891795
# 7       9.00        7.25   7.00               8.00                NaN
# 8       5.75        5.75   6.25               8.00                NaN
# 9       8.00        3.00   5.50               7.00                NaN
# 10      5.75        9.50   3.00               4.50                NaN
# 11      8.75        4.00   2.75               4.75                NaN
# 12       NaN         NaN    NaN                NaN                NaN
# 13       NaN         NaN    NaN                NaN                NaN
# 14      7.00        3.50   2.50               3.50                NaN
# 15      3.00        1.50   2.00               3.75                NaN
# 16      9.75        4.50   9.50               9.25                NaN
# 17      8.75        3.50   9.25               9.00                NaN
# 18      7.25        2.75   7.50               8.50                NaN
# 19      8.25        4.75   5.50               7.00                NaN
# 20      2.00        1.25   7.50               6.50                NaN
# 21      4.25        2.00   7.25               7.75                NaN
# 22      4.50        5.50   3.50               4.75                NaN
# 23      6.67        1.50   9.00               6.33                NaN
# 24      6.00        1.00   7.00               7.00                NaN
# 25       NaN         NaN    NaN                NaN                NaN
# 26      4.00        1.00   8.00               6.00                NaN
# 27      3.25        1.75   3.75               5.25                NaN
# 28      3.50        1.00   7.00               6.50                NaN
# 29      4.00        1.00   6.00               5.00                NaN
# 30      5.00        1.00   5.00               5.00                NaN
# 31      6.50        1.00   3.50               4.50                NaN
# 32      4.00        1.00   3.00               4.00                NaN
# 33      3.00        3.67   3.67               4.67                NaN
# 34      8.00        3.00   8.00               8.25                NaN
# 35      6.75        3.25   8.50               8.00                NaN
# 36      4.50        2.50   7.00               7.00                NaN
# 37      8.00        1.50   7.50               6.50                NaN
# 38      7.00        2.00   7.00               7.50                NaN
# 39       NaN         NaN    NaN                NaN                NaN
# 40      8.25        2.25   5.25               5.25                NaN
# 41      7.00        1.00   7.00               6.00                NaN
# 42      4.00        2.00   8.00               7.00                NaN
# 43      5.50        1.00   3.50               3.50                NaN
#
#        rating  defenders_score  midfielder_score  attacker_score
# 0   53.166530              NaN               NaN             NaN
# 1   51.605332              NaN               NaN             NaN
# 2   47.558709              NaN               NaN             NaN
# 3   46.348189              NaN               NaN             NaN
# 4   43.758526              NaN               NaN             NaN
# 5   42.456083              NaN               NaN             NaN
# 6   26.586249              NaN               NaN             NaN
# 7   65.176454         1.573994               NaN             NaN
# 8   57.731113         1.113734               NaN             NaN
# 9   52.311705         0.489984               NaN             NaN
# 10  45.519098        -0.448090               NaN             NaN
# 11  42.831505        -0.248486               NaN             NaN
# 12  42.071230        -0.050444               NaN             NaN
# 13  41.330953        -0.137535               NaN             NaN
# 14  35.207720        -0.878695               NaN             NaN
# 15  34.472387        -1.414462               NaN             NaN
# 16  57.723887              NaN          1.719183             NaN
# 17  57.532749              NaN          1.490874             NaN
# 18  53.981670              NaN          1.028410             NaN
# 19  52.624694              NaN          0.435414             NaN
# 20  52.504628              NaN          0.250463             NaN
# 21  49.675833              NaN          0.575859             NaN
# 22  47.312429              NaN         -0.225351             NaN
# 23  45.849109              NaN          0.336933             NaN
# 24  42.867348              NaN          0.043217             NaN
# 25  42.535530              NaN          0.004180             NaN
# 26  41.829456              NaN         -0.156589             NaN
# 27  40.101103              NaN         -0.758537             NaN
# 28  39.109730              NaN         -0.423329             NaN
# 29  38.610644              NaN         -0.505639             NaN
# 30  37.473097              NaN         -0.591400             NaN
# 31  34.503221              NaN         -0.940797             NaN
# 32  33.596700              NaN         -1.047447             NaN
# 33  32.512090              NaN         -1.235442             NaN
# 34  66.300775              NaN               NaN        1.668550
# 35  58.347717              NaN               NaN        0.834772
# 36  47.966527              NaN               NaN       -0.060873
# 37  42.849852              NaN               NaN        0.041159
# 38  42.029979              NaN               NaN       -0.055297
# 39  41.829998              NaN               NaN       -0.078824
# 40  41.559462              NaN               NaN       -0.362463
# 41  39.771991              NaN               NaN       -0.320942
# 42  38.774260              NaN               NaN       -0.438322
# 43  32.281671              NaN               NaN       -1.227760
#
# [44 rows x 28 columns]

# %%
df_with_ratings.sort_values(by='rating',ascending=False)
# Out:
#            name position secondary_position  matches  goals  assists  \
# 34         Hito        A                NaN       26     57       22
# 7           Leo        D                 GK       34     40       19
# 35         Prem        A                NaN       27     38       19
# 8          Maki        D                 GK       23      9       16
# 16         Vule        M                NaN        3      8        6
# 17       Martin        M                NaN        9      9        7
# 18        Mario        M                NaN       11     13        8
# 0          Fich       GK                NaN        8      2        1
# 19       Borjan        M                 GK       27     31       19
# 20       Simikj        M                NaN       34     10       24
# 9     Hristijan        D                NaN       25     14       21
# 1          Neno       GK                NaN       29      0        6
# 21         Dare        M                NaN       10     11        9
# 36      Dzhoker        A                NaN       22     24       14
# 2   Ter Stegen        GK                NaN        1      0        0
# 22         Stef        M                 GK       32     22       12
# 3          Stec       GK                NaN       11      0        1
# 23       Davide        M                NaN        3      2        3
# 10         Daco        D                 GK       36      5       11
# 4           Nuh       GK                NaN        4      0        1
# 24          Ron        M                NaN        1      1        0
# 37        Tomas        A                NaN        1      2        0
# 11         Bale        D                NaN       13      2        2
# 25        Theo         M                NaN        1      4        2
# 5         Silbo       GK                NaN        2      0        0
# 12      Stefan         D                NaN        1      1        0
# 38       Gjozo         A                NaN        1      2        1
# 39       Bodan         A                NaN        1      0        3
# 26        Nargo        M                NaN        4      4        3
# 40        Lazo         A                NaN        9     10        7
# 13         Hris        D                NaN        1      0        0
# 27       Grekos        M                NaN       22      7        5
# 41      Gashtar        A                NaN        1      1        1
# 28          Teo        M                NaN        2      0        0
# 42          Jan        A                NaN        1      1        1
# 29       Jancho        M                NaN        3      3        5
# 30        Dimov        M                NaN        1      0        1
# 14       Gorjan        D                NaN        2      0        0
# 31         Leon        M                NaN        1      0        0
# 15        Ancho        D                NaN       27      2        0
# 32     Nikolche        M                NaN        1      2        2
# 33        Filip        M                NaN        4      1        0
# 43        Nikec        A                NaN        2      1        2
# 6       Fishboi       GK                NaN        2      0        0
#
#     gc_per_match  hat-trick  hat-trick-assists  w_percentage  ...  passing  \
# 34          3.04         10                  2          0.46  ...     7.50
# 7           1.74          3                  3          0.35  ...     8.25
# 35          2.11          7                  0          0.41  ...     7.75
# 8           1.09          0                  1          0.52  ...     7.00
# 16          4.67          1                  1          1.00  ...     8.75
# 17          1.78          2                  0          0.33  ...     9.00
# 18          1.91          0                  0          0.55  ...     8.25
# 0           0.38          0                  0          0.25  ...     5.25
# 19          1.85          4                  1          0.63  ...     5.25
# 20          1.00          0                  1          0.41  ...     7.50
# 9           1.40          0                  1          0.52  ...     6.25
# 1           0.21          0                  0          0.38  ...     3.25
# 21          2.00          1                  1          0.30  ...     8.25
# 36          1.73          1                  1          0.32  ...     6.25
# 2           0.00          0                  0          0.00  ...     5.00
# 22          1.06          2                  0          0.44  ...     4.25
# 3           0.09          0                  0          0.55  ...     3.00
# 23          1.67          0                  0          0.00  ...     8.00
# 10          0.44          0                  0          0.36  ...     4.00
# 4           0.25          0                  0          0.50  ...     3.00
# 24          1.00          0                  0          1.00  ...     6.00
# 37          2.00          0                  0          0.00  ...     7.00
# 11          0.31          0                  0          0.23  ...     3.50
# 25          6.00          1                  0          1.00  ...      NaN
# 5           0.00          0                  0          0.50  ...     1.00
# 12          1.00          0                  0          1.00  ...      NaN
# 38          3.00          0                  0          1.00  ...     6.50
# 39          3.00          0                  1          0.00  ...      NaN
# 26          1.75          0                  0          0.25  ...     7.00
# 40          1.89          1                  0          0.33  ...     5.00
# 13          0.00          0                  0          0.00  ...      NaN
# 27          0.55          0                  0          0.23  ...     4.50
# 41          2.00          0                  0          1.00  ...     7.00
# 28          0.00          0                  0          0.50  ...     7.50
# 42          2.00          0                  0          0.00  ...     7.00
# 29          2.67          0                  1          0.33  ...     5.50
# 30          1.00          0                  0          0.00  ...     5.00
# 14          0.00          0                  0          0.50  ...     3.50
# 31          0.00          0                  0          0.00  ...     5.00
# 15          0.07          0                  0          0.37  ...     2.00
# 32          4.00          0                  0          0.00  ...     4.00
# 33          0.25          0                  0          0.50  ...     4.00
# 43          1.50          0                  0          0.50  ...     4.50
# 6           0.00          0                  0          0.50  ...     1.50
#
#     physical  gk_ability  skill  positioning_sense  goalkeepers_score  \
# 34      8.00        3.00   8.00               8.25                NaN
# 7       9.00        7.25   7.00               8.00                NaN
# 35      6.75        3.25   8.50               8.00                NaN
# 8       5.75        5.75   6.25               8.00                NaN
# 16      9.75        4.50   9.50               9.25                NaN
# 17      8.75        3.50   9.25               9.00                NaN
# 18      7.25        2.75   7.50               8.50                NaN
# 0       6.25        9.00   4.25               4.25           0.990595
# 19      8.25        4.75   5.50               7.00                NaN
# 20      2.00        1.25   7.50               6.50                NaN
# 9       8.00        3.00   5.50               7.00                NaN
# 1       5.75        8.00   2.50               2.25           0.160533
# 21      4.25        2.00   7.25               7.75                NaN
# 36      4.50        2.50   7.00               7.00                NaN
# 2       8.00        8.00   5.50               5.50           0.595142
# 22      4.50        5.50   3.50               4.75                NaN
# 3       1.50        8.00   1.25               2.50           0.129444
# 23      6.67        1.50   9.00               6.33                NaN
# 10      5.75        9.50   3.00               4.50                NaN
# 4       2.25        7.25   1.50               2.00           0.052531
# 24      6.00        1.00   7.00               7.00                NaN
# 37      8.00        1.50   7.50               6.50                NaN
# 11      8.75        4.00   2.75               4.75                NaN
# 25       NaN         NaN    NaN                NaN                NaN
# 5       1.00        8.50   1.00               1.00          -0.036450
# 12       NaN         NaN    NaN                NaN                NaN
# 38      7.00        2.00   7.00               7.50                NaN
# 39       NaN         NaN    NaN                NaN                NaN
# 26      4.00        1.00   8.00               6.00                NaN
# 40      8.25        2.25   5.25               5.25                NaN
# 13       NaN         NaN    NaN                NaN                NaN
# 27      3.25        1.75   3.75               5.25                NaN
# 41      7.00        1.00   7.00               6.00                NaN
# 28      3.50        1.00   7.00               6.50                NaN
# 42      4.00        2.00   8.00               7.00                NaN
# 29      4.00        1.00   6.00               5.00                NaN
# 30      5.00        1.00   5.00               5.00                NaN
# 14      7.00        3.50   2.50               3.50                NaN
# 31      6.50        1.00   3.50               4.50                NaN
# 15      3.00        1.50   2.00               3.75                NaN
# 32      4.00        1.00   3.00               4.00                NaN
# 33      3.00        3.67   3.67               4.67                NaN
# 43      5.50        1.00   3.50               3.50                NaN
# 6       1.25        2.50   1.25               1.33          -1.891795
#
#        rating  defenders_score  midfielder_score  attacker_score
# 34  66.300775              NaN               NaN        1.668550
# 7   65.176454         1.573994               NaN             NaN
# 35  58.347717              NaN               NaN        0.834772
# 8   57.731113         1.113734               NaN             NaN
# 16  57.723887              NaN          1.719183             NaN
# 17  57.532749              NaN          1.490874             NaN
# 18  53.981670              NaN          1.028410             NaN
# 0   53.166530              NaN               NaN             NaN
# 19  52.624694              NaN          0.435414             NaN
# 20  52.504628              NaN          0.250463             NaN
# 9   52.311705         0.489984               NaN             NaN
# 1   51.605332              NaN               NaN             NaN
# 21  49.675833              NaN          0.575859             NaN
# 36  47.966527              NaN               NaN       -0.060873
# 2   47.558709              NaN               NaN             NaN
# 22  47.312429              NaN         -0.225351             NaN
# 3   46.348189              NaN               NaN             NaN
# 23  45.849109              NaN          0.336933             NaN
# 10  45.519098        -0.448090               NaN             NaN
# 4   43.758526              NaN               NaN             NaN
# 24  42.867348              NaN          0.043217             NaN
# 37  42.849852              NaN               NaN        0.041159
# 11  42.831505        -0.248486               NaN             NaN
# 25  42.535530              NaN          0.004180             NaN
# 5   42.456083              NaN               NaN             NaN
# 12  42.071230        -0.050444               NaN             NaN
# 38  42.029979              NaN               NaN       -0.055297
# 39  41.829998              NaN               NaN       -0.078824
# 26  41.829456              NaN         -0.156589             NaN
# 40  41.559462              NaN               NaN       -0.362463
# 13  41.330953        -0.137535               NaN             NaN
# 27  40.101103              NaN         -0.758537             NaN
# 41  39.771991              NaN               NaN       -0.320942
# 28  39.109730              NaN         -0.423329             NaN
# 42  38.774260              NaN               NaN       -0.438322
# 29  38.610644              NaN         -0.505639             NaN
# 30  37.473097              NaN         -0.591400             NaN
# 14  35.207720        -0.878695               NaN             NaN
# 31  34.503221              NaN         -0.940797             NaN
# 15  34.472387        -1.414462               NaN             NaN
# 32  33.596700              NaN         -1.047447             NaN
# 33  32.512090              NaN         -1.235442             NaN
# 43  32.281671              NaN               NaN       -1.227760
# 6   26.586249              NaN               NaN             NaN
#
# [44 rows x 28 columns]

# %% [markdown]
# ## Selected players

# %%
to_drop = ['name', 'position','secondary_position','hat-trick','hat-trick-assists','w_percentage','motm','potm','loss_percentage','defenders_score','midfielder_score','attacker_score','goalkeepers_score','fouls_commiting', 'matches']
attributes_list = [attribute for attribute in df_with_ratings.columns.tolist() if attribute not in to_drop]
attributes_list
# Out:
# ['goals',
#  'assists',
#  'gc_per_match',
#  'interceptions_overall_ability',
#  'stamina_rating',
#  'positions_played',
#  'leadership_measure',
#  'passing',
#  'physical',
#  'gk_ability',
#  'skill',
#  'positioning_sense',
#  'rating']

# %% [markdown]
# I assigned these parameters with testing which is good which not ... but i get one conclusion for sure:
# * The importance of the *goals*, *passing* and *stamina_rating* is the most important in small football from my knowledge.

# %%
#CONSTS
EPS = 1e-9
THRESHOLD_CONSTANT = 0.5  #because the normalization process is from 0 to 1, we need to somehow increase the values by a constant that will be valid for the range od [0.5,1]. This constant will scale it correctly.
THRESH = { #attribute-specific tolerances (percentage wise)
    'rating': 0.05,
    'skill': 0.07,
    'passing': 0.07,
    'physical': 0.07,
    'positioning_sense': 0.08,
    'stamina_rating': 0.07,
    'gk_ability': 0.1,
    'gc_per_match': 0.1,
    'goals': 0.15,
    'assists': 0.15,
    'leadership_measure': 0.12,
    'positions_played': 0.12,
    'interceptions_overall_ability': 0.1
}
THRESH = {k: v * THRESHOLD_CONSTANT for k, v in THRESH.items()}  #scaling for keeping it correct

WEIGHTS_OF_IMPORTANCE = { #attribute importance
#41
    'skill': 0.11,  # So important to be good in a small space
    'positioning_sense': 0.11, # The most important thing alongside skill, to know how to position for the ball and to move with the team
    'stamina_rating': 0.1,  # Constant movement and so much energy during the game
    'gc_per_match': 0.09,  # Goal contribution is important to score a goal

#25
    'goals': 0.09,  # Scoring impact
    'assists': 0.08,  # Creating opportunities
    'passing': 0.08,  # Passing is more important to bigger football, but here, with short passes easily can be done to make good plays 
#21
    'physical': 0.06,  # Needed attribute so the player can keep the ball while threatened from the opponent
    'interceptions_overall_ability': 0.06,  # Defensive contribution
    'leadership_measure': 0.05,  # Team organization (not so critical in hobby football, but sometimes important) 
    
#13
    'positions_played': 0.04,  # Flexibility is good, but not that critical in 6v6 football
    'gk_ability': 0.05,  # Relevant for key moments and stability on the goal
    'rating': 0.04,  # general rating must not be taken as something very important because sometimes some statistic are inputting in the rating so much, besides looking the fact that they are not the most important for the player to be considered as a key or not
}

MEAN_METRICS = ['rating', 'passing', 'physical', 'skill', 'positioning_sense', 'stamina_rating', 'leadership_measure',
                'gc_per_match', 'gk_ability', 'positions_played',
                'interceptions_overall_ability']  #these are some ability ratings that need to be averaged per team
SUM_METRICS = ['goals', 'assists']  #these are counting metrics that need to be summarized per team


def total_rating_per_team(team: pd.DataFrame):
    return sum(player['rating'] for player in team)


def attribute_team_statistics(team_df: pd.DataFrame, attribute: str = None) -> dict:
    if attribute is not None and attribute not in attributes_list:
        return {attribute: float(team_df[attribute].mean())} if attribute in MEAN_METRICS else {attribute: float(team_df[attribute].sum())}
    stats = {}
    for attr in attributes_list:
        if attr in MEAN_METRICS:
            stats[attr] = float(team_df[attr].mean())
        if attr in SUM_METRICS:
            stats[attr] = float(team_df[attr].sum())
    return stats


def per_attribute_diff(team_a_summary_stats: dict, team_b_summary_stats: dict) -> dict:
    diffs = {}
    for attr in attributes_list:
        A, B = team_a_summary_stats[attr], team_b_summary_stats[attr]
        diffs[attr] = abs(A - B) / max(abs(A), abs(B), EPS)
    return diffs

def normalize_df(df: pd.DataFrame, columns: list) -> pd.DataFrame:  #normalizing the columns in range [THRESHOLD_CONSTANT, 1]
    df_copy = df.copy()
    for column in columns:
        col = df[column]
        col_min, col_max = np.nanmin(col), np.nanmax(col)
        col_range = col_max - col_min + EPS
        df_copy[column] = THRESHOLD_CONSTANT + (1 - THRESHOLD_CONSTANT) * (col - col_min) / col_range
    return df_copy

# %%
selected_players = ['Stec','Neno','Vule','Hito','Borjan','Prem','Leo','Hristijan','Simikj','Stef','Ancho','Maki']
#selected_players = ['Fishboi','Neno','Leo','Prem','Stef','Simikj','Ancho','Dzhoker','Hristijan','Grekos','Borjan','Daco']

# %%
match_players_df = df_with_ratings[df_with_ratings['name'].isin(selected_players)]
normalized_match_players_df = normalize_df(match_players_df, attributes_list)

# %%
normalized_match_players_df
# Out:
#          name position secondary_position  matches     goals   assists  \
# 1        Neno       GK                NaN       29  0.500000  0.625000
# 3        Stec       GK                NaN       11  0.500000  0.520833
# 7         Leo        D                 GK       34  0.850877  0.895833
# 8        Maki        D                 GK       23  0.578947  0.833333
# 9   Hristijan        D                NaN       25  0.622807  0.937500
# 15      Ancho        D                NaN       27  0.517544  0.500000
# 16       Vule        M                NaN        3  0.570175  0.625000
# 19     Borjan        M                 GK       27  0.771930  0.895833
# 20     Simikj        M                NaN       34  0.587719  1.000000
# 22       Stef        M                 GK       32  0.692982  0.750000
# 34       Hito        A                NaN       26  1.000000  0.958333
# 35       Prem        A                NaN       27  0.833333  0.895833
#
#     gc_per_match  hat-trick  hat-trick-assists  w_percentage  ...   passing  \
# 1       0.515217          0                  0          0.38  ...  0.592593
# 3       0.502174          0                  0          0.55  ...  0.574074
# 7       0.681522          3                  3          0.35  ...  0.962963
# 8       0.610870          0                  1          0.52  ...  0.870370
# 9       0.644565          0                  1          0.52  ...  0.814815
# 15      0.500000          0                  0          0.37  ...  0.500000
# 16      1.000000          1                  1          1.00  ...  1.000000
# 19      0.693478          4                  1          0.63  ...  0.740741
# 20      0.601087          0                  1          0.41  ...  0.907407
# 22      0.607609          2                  0          0.44  ...  0.666667
# 34      0.822826         10                  2          0.46  ...  0.907407
# 35      0.721739          7                  0          0.41  ...  0.925926
#
#     physical  gk_ability     skill  positioning_sense  goalkeepers_score  \
# 1   0.757576    1.000000  0.575758           0.500000           0.160533
# 3   0.500000    1.000000  0.500000           0.517857           0.129444
# 7   0.954545    0.944444  0.848485           0.910714                NaN
# 8   0.757576    0.833333  0.803030           0.910714                NaN
# 9   0.893939    0.629630  0.757576           0.839286                NaN
# 15  0.590909    0.518519  0.545455           0.607143                NaN
# 16  1.000000    0.740741  1.000000           1.000000                NaN
# 19  0.909091    0.759259  0.757576           0.839286                NaN
# 20  0.530303    0.500000  0.878788           0.803571                NaN
# 22  0.681818    0.814815  0.636364           0.678571                NaN
# 34  0.893939    0.629630  0.909091           0.928571                NaN
# 35  0.818182    0.648148  0.939394           0.910714                NaN
#
#       rating  defenders_score  midfielder_score  attacker_score
# 1   0.769146              NaN               NaN             NaN
# 3   0.686560              NaN               NaN             NaN
# 7   0.982338         1.573994               NaN             NaN
# 8   0.865377         1.113734               NaN             NaN
# 9   0.780242         0.489984               NaN             NaN
# 15  0.500000        -1.414462               NaN             NaN
# 16  0.865264              NaN          1.719183             NaN
# 19  0.785159              NaN          0.435414             NaN
# 20  0.783273              NaN          0.250463             NaN
# 22  0.701707              NaN         -0.225351             NaN
# 34  1.000000              NaN               NaN        1.668550
# 35  0.875063              NaN               NaN        0.834772
#
# [12 rows x 28 columns]

# %%
match_gks = normalized_match_players_df[normalized_match_players_df['position'] == 'GK']

# %%
match_outfield = normalized_match_players_df[normalized_match_players_df['position'] != 'GK']

# %%
match_gks = match_gks.sort_values(by='rating', ascending=False).reset_index(drop=True)
match_outfield = match_outfield.sort_values(by='rating', ascending=False).reset_index(drop=True)

# %%
def random_initial_split(players_df: pd.DataFrame, team_size: int = 5):
    shuffled_players = players_df.sample(frac=1, random_state=None).reset_index(drop=True)
    team_a = []
    team_b = []
    for _, player in shuffled_players.iterrows():
        if random.choice(['A', 'B']) == 'A':
            if len(team_a) < team_size:
                team_a.append(player)
            else:
                team_b.append(player)
        else:
            if len(team_b) < team_size:
                team_b.append(player)
            else:
                team_a.append(player)
    team_a_df = pd.DataFrame(team_a)
    team_b_df = pd.DataFrame(team_b)
    return team_a_df, team_b_df

def calculate_imbalance_scores(team_a: pd.DataFrame, team_b: pd.DataFrame):
    #statistics for team A and B
    team_a_statistics = attribute_team_statistics(team_a)
    team_b_statistics = attribute_team_statistics(team_b)

    #difference between the statistics for team A and B
    differences_dictionary = per_attribute_diff(team_a_statistics, team_b_statistics)
    total_contribution = 0.0  #total imbalance score
    flag_dict = {}  #flags for every attribute

    for attr in attributes_list:
        threshold = THRESH.get(attr, 0.1)
        weight = WEIGHTS_OF_IMPORTANCE.get(attr, 0.1)
        difference = differences_dictionary[attr]
        contribution = weight * min(1, max(difference - threshold, 0) / threshold)
        total_contribution += contribution
        flag_dict[attr] = {
            "diff": difference, #the difference in the attribute per team
            "threshold": threshold, #this is the threshold that needs to be the maximum deviation factor, where everything above that is not allowed
            "weight": weight, #the weight of importance defined as constant
            "ok": difference <= threshold, #if the difference is below the threshold, it will be ok = true, otherwise it will be ok = false
            "contribution": contribution #this is the metric for how much does an attribute contribute to the imbalance
        }
    return total_contribution, flag_dict

def position_imbalance_per_team(team_a: pd.DataFrame, team_b: pd.DataFrame) -> bool:
    MAX_POSITION_DIFFERENCE = 1
    POSITIONS = ['D','M','A']
    for position in POSITIONS:
        positions_count_team_a = len(team_a[team_a['position'] == position])
        positions_count_team_b = len(team_b[team_b['position'] == position])
        if abs(positions_count_team_a - positions_count_team_b) > MAX_POSITION_DIFFERENCE:
            return True
    return False
    
def main_hill_climbing_algorithm(initial_team_a: pd.DataFrame,
                                 initial_team_b: pd.DataFrame,
                                 target_ok_ratio=0.75,
                                 max_iterations=10):
    history_trace = []
    tA = initial_team_a.copy()
    tB = initial_team_b.copy()
    best_score, best_flags = calculate_imbalance_scores(tA, tB)
    history_trace.append((best_score, tA.copy()['name'].tolist(), tB.copy()['name'].tolist()))
    for iteration in range(max_iterations):
        improved_flag = False
        best_swap = None
        current_ok_ratio = sum(1 for v in best_flags.values() if v["ok"]) / len(best_flags)
        if current_ok_ratio >= target_ok_ratio:
            print(f'Target OK ratio reached! Breaking at iteration {iteration + 1}')
            break
        for player_a in tA.itertuples():
            for player_b in tB.itertuples():
                temp_a = tA.drop(player_a.Index)._append(tB.loc[[player_b.Index]])
                temp_b = tB.drop(player_b.Index)._append(tA.loc[[player_a.Index]])

                temp_score, temp_flags = calculate_imbalance_scores(temp_a, temp_b)
                new_ok_ratio = sum(1 for v in temp_flags.values() if v["ok"]) / len(temp_flags)
                best_ok_ratio = sum(1 for v in best_flags.values() if v["ok"]) / len(best_flags)

                if new_ok_ratio >= best_ok_ratio and temp_score < best_score:
                    best_score, best_flags = temp_score, temp_flags
                    best_swap = (temp_a, temp_b)
                    improved_flag = True
                    
        if improved_flag:
            tA, tB = best_swap
            history_trace.append((best_score, tA.copy()['name'].tolist(), tB.copy()['name'].tolist()))

    return tA, tB, best_score, best_flags, history_trace

def final_random_restarts_algorithm(match_outfield_df: pd.DataFrame, max_random_restarts=40):
    best_global_score = float("inf")
    best_global_flags = None
    best_global_split_A = None
    best_global_split_B = None
    best_global_trace = None
    for i in range(max_random_restarts):
        print(f'----------------   {i + 1}   ----------------')
        team_a_df, team_b_df = random_initial_split(match_outfield_df)
        tA, tB, score, flag, history_trace = main_hill_climbing_algorithm(team_a_df, team_b_df)
        print(tA["name"].tolist())
        print(tB["name"].tolist())
        print(f'--------------------------------')
        print('')
        if score < best_global_score:
            best_global_score = score
            best_global_flags = flag
            best_global_trace = history_trace
            best_global_split_A = tA
            best_global_split_B = tB
    return best_global_score, best_global_flags, best_global_split_A, best_global_split_B, best_global_trace

# %%
#TESTING
best_score, best_flags, final_team_a, final_team_b, history_trace = final_random_restarts_algorithm(match_outfield)

team_a_stats = attribute_team_statistics(final_team_a)
team_b_stats = attribute_team_statistics(final_team_b)
final_imbalance_score = calculate_imbalance_scores(final_team_a, final_team_b)
# Out:
# ----------------   1   ----------------
# ['Simikj', 'Stef', 'Hito', 'Borjan', 'Maki']
# ['Vule', 'Prem', 'Leo', 'Hristijan', 'Ancho']
# --------------------------------
#
# ----------------   2   ----------------
# ['Maki', 'Simikj', 'Stef', 'Borjan', 'Hito']
# ['Ancho', 'Leo', 'Prem', 'Hristijan', 'Vule']
# --------------------------------
#
# ----------------   3   ----------------
# ['Vule', 'Borjan', 'Stef', 'Prem', 'Hristijan']
# ['Simikj', 'Hito', 'Maki', 'Leo', 'Ancho']
# --------------------------------
#
# ----------------   4   ----------------
# ['Vule', 'Prem', 'Borjan', 'Hristijan', 'Stef']
# ['Hito', 'Maki', 'Ancho', 'Leo', 'Simikj']
# --------------------------------
#
# ----------------   5   ----------------
# ['Ancho', 'Vule', 'Leo', 'Simikj', 'Borjan']
# ['Maki', 'Prem', 'Stef', 'Hristijan', 'Hito']
# --------------------------------
#
# ----------------   6   ----------------
# ['Maki', 'Prem', 'Hito', 'Hristijan', 'Stef']
# ['Leo', 'Borjan', 'Vule', 'Ancho', 'Simikj']
# --------------------------------
#
# ----------------   7   ----------------
# ['Hito', 'Simikj', 'Stef', 'Borjan', 'Maki']
# ['Ancho', 'Leo', 'Hristijan', 'Prem', 'Vule']
# --------------------------------
#
# ----------------   8   ----------------
# ['Borjan', 'Maki', 'Stef', 'Simikj', 'Hito']
# ['Prem', 'Hristijan', 'Leo', 'Ancho', 'Vule']
# --------------------------------
#
# ----------------   9   ----------------
# ['Hristijan', 'Stef', 'Prem', 'Hito', 'Maki']
# ['Vule', 'Leo', 'Ancho', 'Borjan', 'Simikj']
# --------------------------------
#
# ----------------   10   ----------------
# ['Maki', 'Stef', 'Hristijan', 'Prem', 'Hito']
# ['Vule', 'Borjan', 'Ancho', 'Simikj', 'Leo']
# --------------------------------
#
# ----------------   11   ----------------
# ['Ancho', 'Vule', 'Prem', 'Hristijan', 'Leo']
# ['Simikj', 'Stef', 'Hito', 'Borjan', 'Maki']
# --------------------------------
#
# ----------------   12   ----------------
# ['Maki', 'Hito', 'Stef', 'Prem', 'Hristijan']
# ['Ancho', 'Simikj', 'Vule', 'Borjan', 'Leo']
# --------------------------------
#
# ----------------   13   ----------------
# ['Hristijan', 'Vule', 'Hito', 'Borjan', 'Stef']
# ['Leo', 'Ancho', 'Prem', 'Simikj', 'Maki']
# --------------------------------
#
# ----------------   14   ----------------
# ['Maki', 'Simikj', 'Stef', 'Borjan', 'Hito']
# ['Prem', 'Leo', 'Ancho', 'Hristijan', 'Vule']
# --------------------------------
#
# ----------------   15   ----------------
# ['Stef', 'Borjan', 'Simikj', 'Hito', 'Maki']
# ['Ancho', 'Hristijan', 'Vule', 'Prem', 'Leo']
# --------------------------------
#
# ----------------   16   ----------------
# ['Stef', 'Borjan', 'Simikj', 'Hito', 'Maki']
# ['Leo', 'Ancho', 'Prem', 'Vule', 'Hristijan']
# --------------------------------
#
# ----------------   17   ----------------
# ['Hristijan', 'Hito', 'Stef', 'Vule', 'Borjan']
# ['Ancho', 'Simikj', 'Leo', 'Prem', 'Maki']
# --------------------------------
#
# ----------------   18   ----------------
# ['Maki', 'Ancho', 'Hito', 'Leo', 'Simikj']
# ['Vule', 'Hristijan', 'Borjan', 'Prem', 'Stef']
# --------------------------------
#
# ----------------   19   ----------------
# ['Stef', 'Hito', 'Simikj', 'Maki', 'Borjan']
# ['Ancho', 'Leo', 'Prem', 'Hristijan', 'Vule']
# --------------------------------
#
# ----------------   20   ----------------
# ['Prem', 'Hristijan', 'Hito', 'Maki', 'Stef']
# ['Borjan', 'Simikj', 'Vule', 'Ancho', 'Leo']
# --------------------------------
#
# ----------------   21   ----------------
# ['Borjan', 'Maki', 'Stef', 'Simikj', 'Hito']
# ['Vule', 'Hristijan', 'Ancho', 'Prem', 'Leo']
# --------------------------------
#
# ----------------   22   ----------------
# ['Hito', 'Stef', 'Hristijan', 'Vule', 'Borjan']
# ['Maki', 'Prem', 'Ancho', 'Leo', 'Simikj']
# --------------------------------
#
# ----------------   23   ----------------
# ['Maki', 'Hristijan', 'Prem', 'Hito', 'Stef']
# ['Vule', 'Leo', 'Simikj', 'Ancho', 'Borjan']
# --------------------------------
#
# ----------------   24   ----------------
# ['Ancho', 'Simikj', 'Borjan', 'Leo', 'Vule']
# ['Prem', 'Maki', 'Hristijan', 'Hito', 'Stef']
# --------------------------------
#
# ----------------   25   ----------------
# ['Ancho', 'Simikj', 'Leo', 'Vule', 'Borjan']
# ['Prem', 'Hristijan', 'Stef', 'Hito', 'Maki']
# --------------------------------
#
# ----------------   26   ----------------
# ['Borjan', 'Simikj', 'Stef', 'Hito', 'Maki']
# ['Hristijan', 'Ancho', 'Vule', 'Leo', 'Prem']
# --------------------------------
#
# ----------------   27   ----------------
# ['Borjan', 'Prem', 'Stef', 'Vule', 'Hristijan']
# ['Simikj', 'Maki', 'Leo', 'Hito', 'Ancho']
# --------------------------------
#
# ----------------   28   ----------------
# ['Hito', 'Borjan', 'Simikj', 'Maki', 'Stef']
# ['Prem', 'Leo', 'Vule', 'Ancho', 'Hristijan']
# --------------------------------
#
# ----------------   29   ----------------
# ['Hristijan', 'Hito', 'Prem', 'Maki', 'Stef']
# ['Borjan', 'Leo', 'Vule', 'Simikj', 'Ancho']
# --------------------------------
#
# ----------------   30   ----------------
# ['Maki', 'Hito', 'Leo', 'Ancho', 'Simikj']
# ['Borjan', 'Vule', 'Stef', 'Hristijan', 'Prem']
# --------------------------------
#
# ----------------   31   ----------------
# ['Leo', 'Maki', 'Simikj', 'Ancho', 'Prem']
# ['Hristijan', 'Hito', 'Vule', 'Borjan', 'Stef']
# --------------------------------
#
# ----------------   32   ----------------
# ['Leo', 'Hristijan', 'Prem', 'Ancho', 'Vule']
# ['Borjan', 'Hito', 'Simikj', 'Stef', 'Maki']
# --------------------------------
#
# ----------------   33   ----------------
# ['Prem', 'Hristijan', 'Maki', 'Hito', 'Stef']
# ['Borjan', 'Simikj', 'Leo', 'Ancho', 'Vule']
# --------------------------------
#
# ----------------   34   ----------------
# ['Prem', 'Simikj', 'Ancho', 'Leo', 'Maki']
# ['Stef', 'Vule', 'Borjan', 'Hristijan', 'Hito']
# --------------------------------
#
# ----------------   35   ----------------
# ['Maki', 'Stef', 'Borjan', 'Hito', 'Simikj']
# ['Hristijan', 'Ancho', 'Leo', 'Prem', 'Vule']
# --------------------------------
#
# ----------------   36   ----------------
# ['Ancho', 'Simikj', 'Maki', 'Prem', 'Leo']
# ['Stef', 'Hristijan', 'Borjan', 'Vule', 'Hito']
# --------------------------------
#
# ----------------   37   ----------------
# ['Hito', 'Stef', 'Simikj', 'Maki', 'Borjan']
# ['Leo', 'Prem', 'Hristijan', 'Vule', 'Ancho']
# --------------------------------
#
# ----------------   38   ----------------
# ['Vule', 'Hristijan', 'Borjan', 'Stef', 'Hito']
# ['Prem', 'Ancho', 'Simikj', 'Maki', 'Leo']
# --------------------------------
#
# ----------------   39   ----------------
# ['Hristijan', 'Prem', 'Vule', 'Ancho', 'Leo']
# ['Borjan', 'Stef', 'Hito', 'Simikj', 'Maki']
# --------------------------------
#
# ----------------   40   ----------------
# ['Maki', 'Hito', 'Hristijan', 'Prem', 'Stef']
# ['Simikj', 'Borjan', 'Leo', 'Vule', 'Ancho']
# --------------------------------

# %%
print(f'Team A statistics: {team_a_stats}')
print('---------------------------------------')
print(f'Team B statistics: {team_b_stats}')
print('---------------------------------------')
print(f'Imbalances function output SCORE: {final_imbalance_score}')
print('---------------------------------------')
print(f'Team A: {final_team_a['name'].tolist()}')
print(f'Team B: {final_team_b['name'].tolist()}')
print('---------------------------------------')
print(f'The score for this split is {best_score}')
# Out:
# Team A statistics: {'goals': 3.2982456140210834, 'assists': 3.9166666666076395, 'gc_per_match': 0.6952173912619093, 'interceptions_overall_ability': 0.8433333332875556, 'stamina_rating': 0.8071428570989795, 'positions_played': 0.7781249999652344, 'leadership_measure': 0.7896551723738406, 'passing': 0.8222222221744856, 'physical': 0.7969696969337006, 'gk_ability': 0.6925925925640604, 'skill': 0.8060606060235079, 'positioning_sense': 0.8321428570954081, 'rating': 0.7832066634393823}
# ---------------------------------------
# Team B statistics: {'goals': 3.7280701754170513, 'assists': 4.374999999921875, 'gc_per_match': 0.6815217390909736, 'interceptions_overall_ability': 0.8966666666137778, 'stamina_rating': 0.8142857142408163, 'positions_played': 0.7968749999628906, 'leadership_measure': 0.8586206896057075, 'passing': 0.8370370369871057, 'physical': 0.8090909090534435, 'gk_ability': 0.7111111110798353, 'skill': 0.8090909090534435, 'positioning_sense': 0.8535714285209183, 'rating': 0.8444780343313975}
# ---------------------------------------
# Imbalances function output SCORE: (0.14840884187534767, {'goals': {'diff': 0.11529411764570241, 'threshold': 0.075, 'weight': 0.09, 'ok': False, 'contribution': 0.048352941174842894}, 'assists': {'diff': 0.10476190475941027, 'threshold': 0.075, 'weight': 0.08, 'ok': False, 'contribution': 0.03174603174337096}, 'gc_per_match': {'diff': 0.01969981237965917, 'threshold': 0.05, 'weight': 0.09, 'ok': True, 'contribution': 0.0}, 'interceptions_overall_ability': {'diff': 0.05947955389892349, 'threshold': 0.05, 'weight': 0.06, 'ok': False, 'contribution': 0.011375464678708183}, 'stamina_rating': {'diff': 0.008771929823792044, 'threshold': 0.035, 'weight': 0.1, 'ok': True, 'contribution': 0.0}, 'positions_played': {'diff': 0.023529411762860303, 'threshold': 0.06, 'weight': 0.04, 'ok': True, 'contribution': 0.0}, 'leadership_measure': {'diff': 0.08032128513411076, 'threshold': 0.06, 'weight': 0.05, 'ok': False, 'contribution': 0.016934404278425633}, 'passing': {'diff': 0.017699115042681634, 'threshold': 0.035, 'weight': 0.08, 'ok': True, 'contribution': 0.0}, 'physical': {'diff': 0.014981273407117565, 'threshold': 0.035, 'weight': 0.06, 'ok': True, 'contribution': 0.0}, 'gk_ability': {'diff': 0.026041666663953817, 'threshold': 0.05, 'weight': 0.05, 'ok': True, 'contribution': 0.0}, 'skill': {'diff': 0.0037453183517791857, 'threshold': 0.035, 'weight': 0.11, 'ok': True, 'contribution': 0.0}, 'positioning_sense': {'diff': 0.02510460250835937, 'threshold': 0.04, 'weight': 0.11, 'ok': True, 'contribution': 0.0}, 'rating': {'diff': 0.07255531630319531, 'threshold': 0.025, 'weight': 0.04, 'ok': False, 'contribution': 0.04}})
# ---------------------------------------
# Team A: ['Ancho', 'Vule', 'Leo', 'Simikj', 'Borjan']
# Team B: ['Maki', 'Prem', 'Stef', 'Hristijan', 'Hito']
# ---------------------------------------
# The score for this split is 0.14840884187534767

# %%
match_gks
# Out:
#    name position secondary_position  matches  goals   assists  gc_per_match  \
# 0  Neno       GK                NaN       29    0.5  0.625000      0.515217
# 1  Stec       GK                NaN       11    0.5  0.520833      0.502174
#
#    hat-trick  hat-trick-assists  w_percentage  ...   passing  physical  \
# 0          0                  0          0.38  ...  0.592593  0.757576
# 1          0                  0          0.55  ...  0.574074  0.500000
#
#    gk_ability     skill  positioning_sense  goalkeepers_score    rating  \
# 0         1.0  0.575758           0.500000           0.160533  0.769146
# 1         1.0  0.500000           0.517857           0.129444  0.686560
#
#    defenders_score  midfielder_score  attacker_score
# 0              NaN               NaN             NaN
# 1              NaN               NaN             NaN
#
# [2 rows x 28 columns]

# %%
rating_team_a = final_team_a['rating'].sum()
rating_team_b = final_team_b['rating'].sum()

# %%
if rating_team_a < rating_team_b:
    final_team_a = pd.concat([pd.DataFrame([match_gks.iloc[0]]), final_team_a], ignore_index=True)
    final_team_b = pd.concat([pd.DataFrame([match_gks.iloc[1]]), final_team_b], ignore_index=True)
else:
    final_team_b = pd.concat([pd.DataFrame([match_gks.iloc[0]]), final_team_b], ignore_index=True)
    final_team_a = pd.concat([pd.DataFrame([match_gks.iloc[1]]), final_team_a], ignore_index=True)

# %%
final_team_a
# Out:
#      name position secondary_position  matches     goals   assists  \
# 0    Neno       GK                NaN       29  0.500000  0.625000
# 1   Ancho        D                NaN       27  0.517544  0.500000
# 2    Vule        M                NaN        3  0.570175  0.625000
# 3     Leo        D                 GK       34  0.850877  0.895833
# 4  Simikj        M                NaN       34  0.587719  1.000000
# 5  Borjan        M                 GK       27  0.771930  0.895833
#
#    gc_per_match  hat-trick  hat-trick-assists  w_percentage  ...   passing  \
# 0      0.515217          0                  0          0.38  ...  0.592593
# 1      0.500000          0                  0          0.37  ...  0.500000
# 2      1.000000          1                  1          1.00  ...  1.000000
# 3      0.681522          3                  3          0.35  ...  0.962963
# 4      0.601087          0                  1          0.41  ...  0.907407
# 5      0.693478          4                  1          0.63  ...  0.740741
#
#    physical  gk_ability     skill  positioning_sense  goalkeepers_score  \
# 0  0.757576    1.000000  0.575758           0.500000           0.160533
# 1  0.590909    0.518519  0.545455           0.607143                NaN
# 2  1.000000    0.740741  1.000000           1.000000                NaN
# 3  0.954545    0.944444  0.848485           0.910714                NaN
# 4  0.530303    0.500000  0.878788           0.803571                NaN
# 5  0.909091    0.759259  0.757576           0.839286                NaN
#
#      rating  defenders_score  midfielder_score  attacker_score
# 0  0.769146              NaN               NaN             NaN
# 1  0.500000        -1.414462               NaN             NaN
# 2  0.865264              NaN          1.719183             NaN
# 3  0.982338         1.573994               NaN             NaN
# 4  0.783273              NaN          0.250463             NaN
# 5  0.785159              NaN          0.435414             NaN
#
# [6 rows x 28 columns]

# %%
final_team_b
# Out:
#         name position secondary_position  matches     goals   assists  \
# 0       Stec       GK                NaN       11  0.500000  0.520833
# 1       Maki        D                 GK       23  0.578947  0.833333
# 2       Prem        A                NaN       27  0.833333  0.895833
# 3       Stef        M                 GK       32  0.692982  0.750000
# 4  Hristijan        D                NaN       25  0.622807  0.937500
# 5       Hito        A                NaN       26  1.000000  0.958333
#
#    gc_per_match  hat-trick  hat-trick-assists  w_percentage  ...   passing  \
# 0      0.502174          0                  0          0.55  ...  0.574074
# 1      0.610870          0                  1          0.52  ...  0.870370
# 2      0.721739          7                  0          0.41  ...  0.925926
# 3      0.607609          2                  0          0.44  ...  0.666667
# 4      0.644565          0                  1          0.52  ...  0.814815
# 5      0.822826         10                  2          0.46  ...  0.907407
#
#    physical  gk_ability     skill  positioning_sense  goalkeepers_score  \
# 0  0.500000    1.000000  0.500000           0.517857           0.129444
# 1  0.757576    0.833333  0.803030           0.910714                NaN
# 2  0.818182    0.648148  0.939394           0.910714                NaN
# 3  0.681818    0.814815  0.636364           0.678571                NaN
# 4  0.893939    0.629630  0.757576           0.839286                NaN
# 5  0.893939    0.629630  0.909091           0.928571                NaN
#
#      rating  defenders_score  midfielder_score  attacker_score
# 0  0.686560              NaN               NaN             NaN
# 1  0.865377         1.113734               NaN             NaN
# 2  0.875063              NaN               NaN        0.834772
# 3  0.701707              NaN         -0.225351             NaN
# 4  0.780242         0.489984               NaN             NaN
# 5  1.000000              NaN               NaN        1.668550
#
# [6 rows x 28 columns]

# %%
total_contribution, dictionary = calculate_imbalance_scores(final_team_a, final_team_b)
print(f'Imbalance score of final teams:')
print(f'The contribution is {total_contribution}')
[print(f'[{k}] => {v}') for k,v in dictionary.items()]
# Out:
# Imbalance score of final teams:
# The contribution is 0.08885097034610966
# [goals] => {'diff': 0.10165975103607891, 'threshold': 0.075, 'weight': 0.09, 'ok': False, 'contribution': 0.0319917012432947}
# [assists] => {'diff': 0.07234042553006775, 'threshold': 0.075, 'weight': 0.08, 'ok': True, 'contribution': 0.0}
# [gc_per_match] => {'diff': 0.020424836597969877, 'threshold': 0.05, 'weight': 0.09, 'ok': True, 'contribution': 0.0}
# [interceptions_overall_ability] => {'diff': 0.026755852840661908, 'threshold': 0.05, 'weight': 0.06, 'ok': True, 'contribution': 0.0}
# [stamina_rating] => {'diff': 0.033962264147867495, 'threshold': 0.035, 'weight': 0.1, 'ok': True, 'contribution': 0.0}
# [positions_played] => {'diff': 0.003472222221932974, 'threshold': 0.06, 'weight': 0.04, 'ok': True, 'contribution': 0.0}
# [leadership_measure] => {'diff': 0.07526881719782624, 'threshold': 0.06, 'weight': 0.05, 'ok': False, 'contribution': 0.012724014331521871}
# [passing] => {'diff': 0.011673151749882791, 'threshold': 0.035, 'weight': 0.08, 'ok': True, 'contribution': 0.0}
# [physical] => {'diff': 0.041533546322694015, 'threshold': 0.035, 'weight': 0.06, 'ok': False, 'contribution': 0.011200365124618304}
# [gk_ability] => {'diff': 0.02032520325004946, 'threshold': 0.05, 'weight': 0.05, 'ok': True, 'contribution': 0.0}
# [skill] => {'diff': 0.013157894735803565, 'threshold': 0.035, 'weight': 0.11, 'ok': True, 'contribution': 0.0}
# [positioning_sense] => {'diff': 0.0261194029827355, 'threshold': 0.04, 'weight': 0.11, 'ok': True, 'contribution': 0.0}
# [rating] => {'diff': 0.04558430602917174, 'threshold': 0.025, 'weight': 0.04, 'ok': False, 'contribution': 0.03293488964667478}
# [None, None, None, None, None, None, None, None, None, None, None, None, None]

# %%
[print(f'{key}: {value}\n') for key, value in best_flags.items()]
# Out:
# goals: {'diff': 0.11529411764570241, 'threshold': 0.075, 'weight': 0.09, 'ok': False, 'contribution': 0.048352941174842894}
#
# assists: {'diff': 0.10476190475941027, 'threshold': 0.075, 'weight': 0.08, 'ok': False, 'contribution': 0.03174603174337096}
#
# gc_per_match: {'diff': 0.01969981237965917, 'threshold': 0.05, 'weight': 0.09, 'ok': True, 'contribution': 0.0}
#
# interceptions_overall_ability: {'diff': 0.05947955389892349, 'threshold': 0.05, 'weight': 0.06, 'ok': False, 'contribution': 0.011375464678708183}
#
# stamina_rating: {'diff': 0.008771929823792044, 'threshold': 0.035, 'weight': 0.1, 'ok': True, 'contribution': 0.0}
#
# positions_played: {'diff': 0.023529411762860303, 'threshold': 0.06, 'weight': 0.04, 'ok': True, 'contribution': 0.0}
#
# leadership_measure: {'diff': 0.08032128513411076, 'threshold': 0.06, 'weight': 0.05, 'ok': False, 'contribution': 0.016934404278425633}
#
# passing: {'diff': 0.017699115042681634, 'threshold': 0.035, 'weight': 0.08, 'ok': True, 'contribution': 0.0}
#
# physical: {'diff': 0.014981273407117565, 'threshold': 0.035, 'weight': 0.06, 'ok': True, 'contribution': 0.0}
#
# gk_ability: {'diff': 0.026041666663953817, 'threshold': 0.05, 'weight': 0.05, 'ok': True, 'contribution': 0.0}
#
# skill: {'diff': 0.0037453183517791857, 'threshold': 0.035, 'weight': 0.11, 'ok': True, 'contribution': 0.0}
#
# positioning_sense: {'diff': 0.02510460250835937, 'threshold': 0.04, 'weight': 0.11, 'ok': True, 'contribution': 0.0}
#
# rating: {'diff': 0.07255531630319531, 'threshold': 0.025, 'weight': 0.04, 'ok': False, 'contribution': 0.04}
# [None, None, None, None, None, None, None, None, None, None, None, None, None]
